# %% [markdown]
# # Lecture Recorder Notes
#
# Upload `app.py` and `requirements.txt` into this Colab session, then run the cells below.
#
# For law lectures, keep the original OBS recording. The transcript is a working copy and should be checked against the audio for exact wording.

# %%
# !pip install -r requirements.txt

# %%
# Optional, but recommended if your audio files are in Google Drive.
from google.colab import drive
drive.mount('/content/drive')

# %%
# Optional: choose speed/accuracy before launching.
# tiny/base = faster, less accurate. small = balanced. medium = slower, more accurate.
# %env WHISPER_MODEL_SIZE=small

# %%
# !python app.py
